# %% [markdown]
# # Columns Operations and More
#
# We are going to use IMDB Top-250 movies dataset in this example.
# You can download the dataset with link in the below.
#
# https://www.kaggle.com/datasets/yehorkorzh/imdb-top-250-movies

# %%
# 1-Import the pandas library and alias it as pd.
import pandas as pd

# %%
# 2-Import the dataset and assign it to a variable named films.

films = pd.read_csv("imdb_movies.csv")
films.head()
# Out:
#    Unnamed: 0  Num                     Title  Year     Released  Runtime  \
# 0           0    1  The Shawshank Redemption  1994  14 Oct 1994  142 min
# 1           1    2             The Godfather  1972  24 Mar 1972  175 min
# 2           2    3    The Godfather: Part II  1974  20 Dec 1974  202 min
# 3           3    4           The Dark Knight  2008  18 Jul 2008  152 min
# 4           4    5              12 Angry Men  1957  01 Apr 1957   96 min
#
#                   Genre              Director  \
# 0          Crime, Drama        Frank Darabont
# 1          Crime, Drama  Francis Ford Coppola
# 2          Crime, Drama  Francis Ford Coppola
# 3  Action, Crime, Drama     Christopher Nolan
# 4          Crime, Drama          Sidney Lumet
#
#                                               Writer  \
# 0  Stephen King (short story "Rita Hayworth and S...
# 1  Mario Puzo (screenplay), Francis Ford Coppola ...
# 2  Francis Ford Coppola (screenplay), Mario Puzo ...
# ...

# %%
# 3-What are the names of the columns?

films.columns
# Out:
# Index(['Unnamed: 0', 'Num', 'Title', 'Year', 'Released', 'Runtime', 'Genre',
#        'Director', 'Writer', 'Actors', 'Plot', 'Language', 'Country', 'Awards',
#        'Metascore', 'imdbRating', 'imdbVotes', 'imdbID', 'Type', 'DVD',
#        'BoxOffice', 'Production', 'Website'],
#       dtype='object')

# %%
# 4-Set the 'Num' column as the index of the dataframe

films.set_index("Num",inplace=True)

# %%
# 5-Drop the "Unnamed: 0" column from the dataset.

films.drop(columns="Unnamed: 0",inplace=True)

# %%
# 6-Print only the column Title

films.Title
# Out:
# Num
# 1      The Shawshank Redemption
# 2                 The Godfather
# 3        The Godfather: Part II
# 4               The Dark Knight
# 5                  12 Angry Men
#                  ...
# 246            The Lost Weekend
# 247               Short Term 12
# 248             His Girl Friday
# 249          The Straight Story
# 250         Slumdog Millionaire
# Name: Title, Length: 250, dtype: object

# %%
# 7-Print the columns 'Title' and 'Genre'.

films[["Title","Genre"]]
# Out:
#                         Title                   Genre
# Num
# 1    The Shawshank Redemption            Crime, Drama
# 2               The Godfather            Crime, Drama
# 3      The Godfather: Part II            Crime, Drama
# 4             The Dark Knight    Action, Crime, Drama
# 5                12 Angry Men            Crime, Drama
# ..                        ...                     ...
# 246          The Lost Weekend        Drama, Film-Noir
# 247             Short Term 12                   Drama
# 248           His Girl Friday  Comedy, Drama, Romance
# 249        The Straight Story        Biography, Drama
# 250       Slumdog Millionaire                   Drama
#
# [250 rows x 2 columns]

# %%
# 8-Select the 'Title', 'Runtime' and 'Genre' columns from row 1-2 and 3 .

films.loc[[1,2,3],["Title","Runtime","Genre"]]
# Out:
#                         Title  Runtime         Genre
# Num
# 1    The Shawshank Redemption  142 min  Crime, Drama
# 2               The Godfather  175 min  Crime, Drama
# 3      The Godfather: Part II  202 min  Crime, Drama

# %%
# 9- Select the rows 3 to 7 and the columns 3 to 6

films.iloc[2:7,2:6]
# Out:
#         Released  Runtime                      Genre              Director
# Num
# 3    20 Dec 1974  202 min               Crime, Drama  Francis Ford Coppola
# 4    18 Jul 2008  152 min       Action, Crime, Drama     Christopher Nolan
# 5    01 Apr 1957   96 min               Crime, Drama          Sidney Lumet
# 6    04 Feb 1994  195 min  Biography, Drama, History      Steven Spielberg
# 7    17 Dec 2003  201 min  Adventure, Drama, Fantasy         Peter Jackson

# %%
# 10-Select every row after the fourth row and all columns

films.iloc[4:,:]
# Out:
#                                              Title  Year     Released  \
# Num
# 5                                     12 Angry Men  1957  01 Apr 1957
# 6                                 Schindler's List  1993  04 Feb 1994
# 7    The Lord of the Rings: The Return of the King  2003  17 Dec 2003
# 8                                     Pulp Fiction  1994  14 Oct 1994
# 9                                       Fight Club  1999  15 Oct 1999
# ..                                             ...   ...          ...
# 246                               The Lost Weekend  1945  01 Jan 1946
# 247                                  Short Term 12  2013  23 Aug 2013
# 248                                His Girl Friday  1940  18 Jan 1940
# 249                             The Straight Story  1999  03 Nov 1999
# 250                            Slumdog Millionaire  2008  25 Dec 2008
#
#      Runtime                      Genre                      Director  \
# Num
# ...

# %%
# 11-Select rows where film.Runtime is greater than 140.

# First we have to change our Runtime column type as integer after that we can use ">" operators.

films.Runtime.astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/zw/gl254gt53sj63lwkw8g21dsm0000gn/T/ipykernel_7135/3040347654.py in <module>
#       3 # First we have to change our Runtime column type as integer after that we can use ">" operators.
#       4
# ----> 5 films.Runtime.astype(int)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     417
# ...

# %%
# We have to clean our data because while we try to change our data type error occur we need to fix it.

films.Runtime = films.Runtime.str.strip(" min")

# %%
films.Runtime = films.Runtime.astype(int)

# %%
films[films.Runtime>140]
# Out:
#                         Title  Year     Released  Runtime  \
# Num
# 1    The Shawshank Redemption  1994  14 Oct 1994      142
# 2               The Godfather  1972  24 Mar 1972      175
# 3      The Godfather: Part II  1974  20 Dec 1974      202
# 4             The Dark Knight  2008  18 Jul 2008      152
# 6            Schindler's List  1993  04 Feb 1994      195
# ..                        ...   ...          ...      ...
# 233                       JFK  1991  20 Dec 1991      189
# 235             Blood Diamond  2006  08 Dec 2006      143
# 236                  Magnolia  1999  07 Jan 2000      188
# 238              The Revenant  2015  08 Jan 2016      156
# 245                    Patton  1970  02 Apr 1970      172
#
#                           Genre                     Director  \
# Num
# 1                  Crime, Drama               Frank Darabont
# 2                  Crime, Drama         Francis Ford Coppola
# 3                  Crime, Drama         Francis Ford Coppola
# ...

# %%
# 12-Rename Runtime column and make it understandable (Runtime (min)).

films.rename(columns={"Runtime":"Runtime (min)"},inplace=True)
films[["Title","Runtime (min)"]]
# Out:
#                         Title  Runtime (min)
# Num
# 1    The Shawshank Redemption            142
# 2               The Godfather            175
# 3      The Godfather: Part II            202
# 4             The Dark Knight            152
# 5                12 Angry Men             96
# ..                        ...            ...
# 246          The Lost Weekend            101
# 247             Short Term 12             96
# 248           His Girl Friday             92
# 249        The Straight Story            112
# 250       Slumdog Millionaire            120
#
# [250 rows x 2 columns]

# %%
# 13-Select rows where Runtime is greater than 210 or less than 80

filt = (films["Runtime (min)"] > 210) | (films["Runtime (min)"]<80)
films[filt]
# Out:
#                               Title  Year     Released  Runtime (min)  \
# Num
# 55      Once Upon a Time in America  1984  01 Jun 1984            229
# 65               Lawrence of Arabia  1962  11 Dec 1962            216
# 66                          The Kid  1921  06 Feb 1921             68
# 103                     The General  1926  24 Feb 1927             67
# 119              Gone with the Wind  1939  17 Jan 1940            238
# 147                         Ben-Hur  1959  29 Jan 1960            212
# 239  The Nightmare Before Christmas  1993  29 Oct 1993             76
#
#                            Genre                                Director  \
# Num
# 55                  Crime, Drama                            Sergio Leone
# 65   Adventure, Biography, Drama                              David Lean
# 66         Comedy, Drama, Family                         Charles Chaplin
# 103    Action, Adventure, Comedy           Clyde Bruckman, Buster Keaton
# ...
